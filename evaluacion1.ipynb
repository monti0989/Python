# %% [markdown]
# <a href="https://colab.research.google.com/github/monti0989/Python/blob/main/evaluacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escribir un programa que pregunte al usuario su nombre, y luego lo salude.
nombre = input ("Introduce tu nombre:")
print(f"! Hola,  {nombre} ¡")
# Out:
# Introduce tu nombre:ivan
# ! Hola,  ivan ¡

# %% [markdown]
# 1.- Es un lenguaje de programacion similar a perl, pero con una sintexis mas legible
#
#
# 2.- UNIX, Solaris, Linux, DOS, Windows, OS/2, Mac OS
